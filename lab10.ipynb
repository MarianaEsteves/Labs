# %% [markdown]
# # Lab 10
#
# Suppose you have a list of positions of possible clients of Uber in Lisbon (Passageiros.csv). How many cars could you use and where they could be positioned in order to reduce time? Use a cluster analysis appraoch to support the solution of this problem.
#
# * import the libraries needed
# * import dataset from Passageiros.csv file
# * Verify imported data
# * verify data types and convert into numeric if needed. Use for example, df['x']=pd.to_numeric(df['x'], errors='coerce')
# * plot a scatter chart
# * create a X dataframe including only numeric columns
# * calculete WCSS using X dataframe:
#
#     wcss = []
#
#     for i in range(1, 11):
#
#         kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
#
#         kmeans.fit(df)
#
#         wcss.append(kmeans.inertia_)
#
#     plt.plot(range(1, 11), wcss)
#
#     plt.title('Elbow Method')
#
#     plt.xlabel('Number of clusters')
#
#     plt.ylabel('WCSS')
#
#     plt.show()
#
#     plot a scatter chart showing centroids of the clusters estimated

# %%
import pandas as pd
dataframe=pd.read_csv(r"C:\Users\Federico\Dropbox\5 tecnicas de program\codici\Passageiros.csv", sep=",")

# %%
type(dataframe)
dataframe.infer_objects()
# Out:
#            X          Y           Name
# 0  -9.163874  38.711563   Passageiro 1
# 1  -9.199447  38.703342   Passageiro 2
# 2  -9.143752  38.729060   Passageiro 3
# 3  -9.150410  38.755656   Passageiro 4
# 4  -9.136334  38.758534   Passageiro 5
# 5  -9.140453  38.748461   Passageiro 6
# 6  -9.139724  38.745850   Passageiro 7
# 7  -9.130282  38.741440   Passageiro 8
# 8  -9.129789  38.738896   Passageiro 9
# 9  -9.134788  38.735097  Passageiro 10
# 10 -9.141505  38.733247  Passageiro 11
# 11 -9.140646  38.733205  Passageiro 12
# 12 -9.166632  38.744863  Passageiro 13
# 13 -9.173820  38.742352  Passageiro 14
# 14 -9.158070  38.734770  Passageiro 15
# 15 -9.156337  38.739327  Passageiro 16
# 16 -9.144273  38.739750  Passageiro 17
# 17 -9.147363  38.741055  Passageiro 18
# 18 -9.152212  38.739222  Passageiro 19
# 19 -9.149745  38.737323  Passageiro 20
# 20 -9.153167  38.733849  Passageiro 21
# 21 -9.199612  38.755899  Passageiro 22
# 22 -9.198984  38.753970  Passageiro 23
# 23 -9.205057  38.753351  Passageiro 24
# 24 -9.190857  38.748896  Passageiro 25
# 25 -9.153805  38.765528  Passageiro 26
# 26 -9.153752  38.767594  Passageiro 27
# 27 -9.153966  38.767607  Passageiro 28
# 28 -9.142385  38.748946  Passageiro 29
# 29 -9.143157  38.752376  Passageiro 30
# 30 -9.141033  38.748109  Passageiro 31
# 31 -9.130797  38.746285  Passageiro 32
# 32 -9.161825  38.762642  Passageiro 33
# 33 -9.144662  38.714212  Passageiro 34
# 34 -9.162694  38.737055  Passageiro 35
# 35 -9.150061  38.742875  Passageiro 36
# 36 -9.155849  38.743858  Passageiro 37
# 37 -9.146499  38.730598  Passageiro 38
# 38 -9.148382  38.732565  Passageiro 39
# 39 -9.151043  38.724124  Passageiro 40
# 40 -9.147605  38.724807  Passageiro 41
# 41 -9.151322  38.780141  Passageiro 42
# 42 -9.145148  38.721522  Passageiro 43
# 43 -9.145092  38.721455  Passageiro 44
# 44 -9.149303  38.729795  Passageiro 45
# 45 -9.167609  38.737635  Passageiro 46
# 46 -9.170369  38.715748  Passageiro 47
# 47 -9.095090  38.781448  Passageiro 48
# 48 -9.134640  38.732671  Passageiro 49
# 49 -9.135825  38.745150  Passageiro 50
# 50 -9.098315  38.791291  Passageiro 51
# 51 -9.114688  38.762719  Passageiro 52
# 52 -9.143116  38.740701  Passageiro 53
# 53 -9.150082  38.745868  Passageiro 54
# 54 -9.158241  38.706738  Passageiro 55

# %%
dataframe1=dataframe.drop("Name", axis=1)
 
dataframe1.infer_objects()
# Out:
#            X          Y
# 0  -9.163874  38.711563
# 1  -9.199447  38.703342
# 2  -9.143752  38.729060
# 3  -9.150410  38.755656
# 4  -9.136334  38.758534
# 5  -9.140453  38.748461
# 6  -9.139724  38.745850
# 7  -9.130282  38.741440
# 8  -9.129789  38.738896
# 9  -9.134788  38.735097
# 10 -9.141505  38.733247
# 11 -9.140646  38.733205
# 12 -9.166632  38.744863
# 13 -9.173820  38.742352
# 14 -9.158070  38.734770
# 15 -9.156337  38.739327
# 16 -9.144273  38.739750
# 17 -9.147363  38.741055
# 18 -9.152212  38.739222
# 19 -9.149745  38.737323
# 20 -9.153167  38.733849
# 21 -9.199612  38.755899
# 22 -9.198984  38.753970
# 23 -9.205057  38.753351
# 24 -9.190857  38.748896
# 25 -9.153805  38.765528
# 26 -9.153752  38.767594
# 27 -9.153966  38.767607
# 28 -9.142385  38.748946
# 29 -9.143157  38.752376
# 30 -9.141033  38.748109
# 31 -9.130797  38.746285
# 32 -9.161825  38.762642
# 33 -9.144662  38.714212
# 34 -9.162694  38.737055
# 35 -9.150061  38.742875
# 36 -9.155849  38.743858
# 37 -9.146499  38.730598
# 38 -9.148382  38.732565
# 39 -9.151043  38.724124
# 40 -9.147605  38.724807
# 41 -9.151322  38.780141
# 42 -9.145148  38.721522
# 43 -9.145092  38.721455
# 44 -9.149303  38.729795
# 45 -9.167609  38.737635
# 46 -9.170369  38.715748
# 47 -9.095090  38.781448
# 48 -9.134640  38.732671
# 49 -9.135825  38.745150
# 50 -9.098315  38.791291
# 51 -9.114688  38.762719
# 52 -9.143116  38.740701
# 53 -9.150082  38.745868
# 54 -9.158241  38.706738

# %%
dataframe['X']=pd.to_numeric(dataframe['X'], errors='coerce')
dataframe['Y']=pd.to_numeric(dataframe['Y'],errors='coerce')
dataframe.info()
x=(dataframe['X'],dataframe['Y'])
print(x)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 3 columns):
# X       55 non-null float64
# Y       55 non-null float64
# Name    55 non-null object
# dtypes: float64(2), object(1)
# memory usage: 1.4+ KB
# (0    -9.163874
# 1    -9.199447
# 2    -9.143752
# 3    -9.150410
# 4    -9.136334
# 5    -9.140453
# 6    -9.139724
# 7    -9.130282
# 8    -9.129789
# 9    -9.134788
# 10   -9.141505
# 11   -9.140646
# 12   -9.166632
# 13   -9.173820
# 14   -9.158070
# 15   -9.156337
# 16   -9.144273
# 17   -9.147363
# 18   -9.152212
# 19   -9.149745
# 20   -9.153167
# 21   -9.199612
# 22   -9.198984
# 23   -9.205057
# 24   -9.190857
# 25   -9.153805
# 26   -9.153752
# 27   -9.153966
# 28   -9.142385
# 29   -9.143157
# 30   -9.141033
# 31   -9.130797
# 32   -9.161825
# 33   -9.144662
# 34   -9.162694
# 35   -9.150061
# 36   -9.155849
# 37   -9.146499
# 38   -9.148382
# 39   -9.151043
# 40   -9.147605
# 41   -9.151322
# 42   -9.145148
# 43   -9.145092
# 44   -9.149303
# 45   -9.167609
# 46   -9.170369
# 47   -9.095090
# 48   -9.134640
# 49   -9.135825
# 50   -9.098315
# 51   -9.114688
# 52   -9.143116
# 53   -9.150082
# 54   -9.158241
# Name: X, dtype: float64, 0     38.711563
# 1     38.703342
# 2     38.729060
# 3     38.755656
# 4     38.758534
# 5     38.748461
# 6     38.745850
# 7     38.741440
# 8     38.738896
# 9     38.735097
# 10    38.733247
# 11    38.733205
# 12    38.744863
# 13    38.742352
# 14    38.734770
# 15    38.739327
# 16    38.739750
# 17    38.741055
# 18    38.739222
# 19    38.737323
# 20    38.733849
# 21    38.755899
# 22    38.753970
# 23    38.753351
# 24    38.748896
# 25    38.765528
# 26    38.767594
# 27    38.767607
# 28    38.748946
# 29    38.752376
# 30    38.748109
# 31    38.746285
# 32    38.762642
# 33    38.714212
# 34    38.737055
# 35    38.742875
# 36    38.743858
# 37    38.730598
# 38    38.732565
# 39    38.724124
# 40    38.724807
# 41    38.780141
# 42    38.721522
# 43    38.721455
# 44    38.729795
# 45    38.737635
# 46    38.715748
# 47    38.781448
# 48    38.732671
# 49    38.745150
# 50    38.791291
# 51    38.762719
# 52    38.740701
# 53    38.745868
# 54    38.706738
# Name: Y, dtype: float64)

# %%
import numpy as np
import matplotlib.pyplot as plt


# Plot
plt.scatter(dataframe['X'],dataframe['Y'])
plt.title('Passageiros')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
wcss = []
for i in range(1, 11):
  kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)

  kmeans.fit(dataframe1)

  wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
df['a']=pd.to_numeric(df['a'], errors='coerce')
df['b']=pd.to_numeric(df['b'],errors='coerce')
df.info() 
a=-dataframe1['X']
b=dataframe1['Y']
a.infer_objects()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
# a    1 non-null object
# b    1 non-null object
# dtypes: object(2)
# memory usage: 96.0+ bytes
# 0     9.163874
# 1     9.199447
# 2     9.143752
# 3     9.150410
# 4     9.136334
# 5     9.140453
# 6     9.139724
# 7     9.130282
# 8     9.129789
# 9     9.134788
# 10    9.141505
# 11    9.140646
# 12    9.166632
# 13    9.173820
# 14    9.158070
# 15    9.156337
# 16    9.144273
# 17    9.147363
# 18    9.152212
# 19    9.149745
# 20    9.153167
# 21    9.199612
# 22    9.198984
# 23    9.205057
# 24    9.190857
# 25    9.153805
# 26    9.153752
# 27    9.153966
# 28    9.142385
# 29    9.143157
# 30    9.141033
# 31    9.130797
# 32    9.161825
# 33    9.144662
# 34    9.162694
# 35    9.150061
# 36    9.155849
# 37    9.146499
# 38    9.148382
# 39    9.151043
# 40    9.147605
# 41    9.151322
# 42    9.145148
# 43    9.145092
# 44    9.149303
# 45    9.167609
# 46    9.170369
# 47    9.095090
# 48    9.134640
# 49    9.135825
# 50    9.098315
# 51    9.114688
# 52    9.143116
# 53    9.150082
# 54    9.158241
# Name: X, dtype: float64

# %%
from pandas import DataFrame 
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans 


import pandas as pd
data=pd.read_csv(r"C:\Users\Federico\Dropbox\5 tecnicas de program\codici\Passageiros.csv", sep=",")
print(data)
from pandas import DataFrame 
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans
# Out:
#            X          Y           Name
# 0  -9.163874  38.711563   Passageiro 1
# 1  -9.199447  38.703342   Passageiro 2
# 2  -9.143752  38.729060   Passageiro 3
# 3  -9.150410  38.755656   Passageiro 4
# 4  -9.136334  38.758534   Passageiro 5
# 5  -9.140453  38.748461   Passageiro 6
# 6  -9.139724  38.745850   Passageiro 7
# 7  -9.130282  38.741440   Passageiro 8
# 8  -9.129789  38.738896   Passageiro 9
# 9  -9.134788  38.735097  Passageiro 10
# 10 -9.141505  38.733247  Passageiro 11
# 11 -9.140646  38.733205  Passageiro 12
# 12 -9.166632  38.744863  Passageiro 13
# 13 -9.173820  38.742352  Passageiro 14
# 14 -9.158070  38.734770  Passageiro 15
# 15 -9.156337  38.739327  Passageiro 16
# 16 -9.144273  38.739750  Passageiro 17
# 17 -9.147363  38.741055  Passageiro 18
# 18 -9.152212  38.739222  Passageiro 19
# 19 -9.149745  38.737323  Passageiro 20
# 20 -9.153167  38.733849  Passageiro 21
# 21 -9.199612  38.755899  Passageiro 22
# 22 -9.198984  38.753970  Passageiro 23
# 23 -9.205057  38.753351  Passageiro 24
# 24 -9.190857  38.748896  Passageiro 25
# 25 -9.153805  38.765528  Passageiro 26
# 26 -9.153752  38.767594  Passageiro 27
# 27 -9.153966  38.767607  Passageiro 28
# 28 -9.142385  38.748946  Passageiro 29
# 29 -9.143157  38.752376  Passageiro 30
# 30 -9.141033  38.748109  Passageiro 31
# 31 -9.130797  38.746285  Passageiro 32
# 32 -9.161825  38.762642  Passageiro 33
# 33 -9.144662  38.714212  Passageiro 34
# 34 -9.162694  38.737055  Passageiro 35
# 35 -9.150061  38.742875  Passageiro 36
# 36 -9.155849  38.743858  Passageiro 37
# 37 -9.146499  38.730598  Passageiro 38
# 38 -9.148382  38.732565  Passageiro 39
# 39 -9.151043  38.724124  Passageiro 40
# 40 -9.147605  38.724807  Passageiro 41
# 41 -9.151322  38.780141  Passageiro 42
# 42 -9.145148  38.721522  Passageiro 43
# 43 -9.145092  38.721455  Passageiro 44
# 44 -9.149303  38.729795  Passageiro 45
# 45 -9.167609  38.737635  Passageiro 46
# 46 -9.170369  38.715748  Passageiro 47
# 47 -9.095090  38.781448  Passageiro 48
# 48 -9.134640  38.732671  Passageiro 49
# 49 -9.135825  38.745150  Passageiro 50
# 50 -9.098315  38.791291  Passageiro 51
# 51 -9.114688  38.762719  Passageiro 52
# 52 -9.143116  38.740701  Passageiro 53
# 53 -9.150082  38.745868  Passageiro 54
# 54 -9.158241  38.706738  Passageiro 55

# %%
df= data.drop("Name", axis=1)
kmeans=KMeans(n_clusters=3).fit(df)

# %%
centroids= kmeans.cluster_centers_
print(centroids)
# Out:
# [[-9.1946297  38.7429683 ]
#  [-9.1540218  38.72831145]
#  [-9.15417998 38.76652808]
#  [-9.10269783 38.7784862 ]
#  [-9.14060509 38.74311868]]

# %%
#kMean plot
plt.scatter(df['X'],df['Y'], c =kmeans.labels_.astype(float),s=50 , alpha=0.5)
plt.scatter(centroids[:,0],centroids[:,1],c='red',s=50)
